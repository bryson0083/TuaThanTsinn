# %% [markdown]
# # 台股選股清單
# ## 選股條件
# * KD值低於30，五日平均交易量大於1000張，本益比小於20倍

# %%
import os
import sys
from datetime import date
from datetime import datetime
from pathlib import Path

import pandas as pd

# %%
from finlab import data
import finlab

# %%
# 引用自建公用模組
sys.path.insert(0, str(Path.cwd().parent))
from proj_util_pkg.settings import ProjEnvSettings

from proj_util_pkg.finlab_api import finlab_manager as flm
from proj_util_pkg.google_api import gspread_manager as gsm
from proj_util_pkg.common import tw_stock_topic as tst
# Out:
# ✅ 成功載入環境變數檔案: /Users/bryson0083/projects/TuaThanTsinn/src/TuaThanTsinn/proj_util_pkg/config/.env
# [環境變數]PROJECT_ROOT: /Users/bryson0083/projects/TuaThanTsinn/src/TuaThanTsinn

# %% [markdown]
# ## 公用參數設定

# %%
# finlab api 服務初始化
finlab = flm.FinlabManager()
data.force_cloud_download = False
# Out:
# 輸入成功!

# %%
# 資訊輸出Google SpreadSheet 表單參數設定
GSPERAD_SHEET_KEY = os.environ.get('gspread_wb_key')  # Google SpreadSheet 表單ID
OUTPUT_GSHEET_NAME = '選股清單01'

# %%
# 本地報表輸出路徑
REPORT_PATH = os.environ.get('report_path')

# %% [markdown]
# ## 外部資料讀取

# %%
# 讀取台股收盤價資訊
close = data.get("price:收盤價", save_to_storage=True)
vol = data.get("price:成交股數", save_to_storage=True)
stock_info = data.get('company_basic_info', save_to_storage=True)
pe_ratio = data.get('price_earning_ratio:本益比', save_to_storage=True)
pb_ratio = data.get('price_earning_ratio:股價淨值比', save_to_storage=True)
institutional_investors_foreign = data.get('institutional_investors_trading_summary:外陸資買賣超股數(不含外資自營商)', save_to_storage=True)
institutional_investors_inv_trust = data.get('institutional_investors_trading_summary:投信買賣超股數', save_to_storage=True)
institutional_investors_dealer = data.get('institutional_investors_trading_summary:自營商買賣超股數(避險)', save_to_storage=True)
# Out:
# Your version is 1.5.6, please install a newer version.
# Use "pip install finlab==1.5.7" to update the latest version.

# %% [markdown]
# ## 數據分析

# %%
start_time = datetime.now()
print(f"ANA001_台股選股 「KD選股」 分析開始時間: {start_time}")
# Out:
# ANA001_台股選股 「KD選股」 分析開始時間: 2026-02-27 16:24:21.964181

# %%
stock_name = stock_info[['stock_id', '公司簡稱']]
stock_name = stock_name.rename(columns={'stock_id': 'symbol'})

# %%
# stock_name

# %%
sma18 = close.average(18)
sma50 = close.average(50)
vol_avg5 = vol.average(5)

# %%
# # 篩選連三漲
# rise18_df = sma18.rise().sustain(3).tail(1)

# %%
# rise18_df

# %%
# 條件篩選
df2 = sma18 > sma50

today = date.today().strftime("%Y-%m-%d")
# today = "2024-05-31"
# filtered_df2 = df2[df2.index == today]
filtered_df2 = df2.tail(1)

filtered_df2
# Out:
# symbol       0015  0050  0051  0052  0053   0054  0055  0056  0057   0058  \
# date
# 2026-02-26  False  True  True  True  True  False  True  True  True  False
#
# symbol      ...   9944   9945   9946  9949  9950   9951  9955   9958  9960  \
# date        ...
# 2026-02-26  ...  False  False  False  True  True  False  True  False  True
#
# symbol      9962
# date
# 2026-02-26  True
#
# [1 rows x 2709 columns]

#  '00981A',
#  '00981T',
#  '00982A',
#  '00982B',
#  '00982D',
#  '00982T',
#  '00983D',
#  '00984A',
#  '00984B',
#  '00985A',
#  '00985B',
#  '00986A',
#  '00986B',
#  '00987A',
#  '00988A',
#  '00990A',
#  '00991A',
#  '00992A',
#  '00994A',
#  '01001T',
#  '01002T',
#  '01004T',
#  '01007T',
#  '01010T',
#  '02001L',
#  '020020',
#  '020025',
#  '020027',
#  '020028',
#  '020029',
#  '020030',
#  '020031',
#  '020032',
#  '020034',
#  '020035',
#  '020037',
#  '020038',
#  '020039',
#  '020040',
#  '1101',
#  '1101B',
#  '1103',
#  '1108',
#  '1203',
#  '1215',
#  '1217',
#  '1218',
#  '1219',
#  '1220',
#  '1232',
#  '1233',
#  '1236',
#  '1240',
#  '1256',
#  '1268',
#  '1294',
#  '1301',
#  '1303',
#  '1304',
#  '1305',
#  '1307',
#  '1308',
#  '1309',
#  '1310',
#  '1312',
#  '1312A',
#  '1313',
#  '1314',
#  '1315',
#  '1319',
#  '1326',
#  '1337',
#  '1341',
#  '1342',
#  '1402',
#  '1409',
#  '1414',
#  '1418',
#  '1419',
#  '1432',
#  '1434',
#  '1439',
#  '1440',
#  '1443',
#  '1444',
#  '1445',
#  '1447',
#  '1451',
#  '1453',
#  '1454',
#  '1455',
#  '1459',
#  '1460',
#  '1466',
#  '1467',
#  '1468',
#  '1470',
#  '1471',
#  '1473',
#  '1475',
#  '1476',
#  '1477',
#  '1503',
#  '1506',
#  '1512',
#  '1513',
#  '1514',
#  '1516',
#  '1517',
#  '1519',
#  '1521',
#  '1522',
#  '1522A',
#  '1524',
#  '1526',
#  '1527',
#  '1528',
#  '1529',
#  '1530',
#  '1531',
#  '1536',
#  '1539',
#  '1540',
#  '1541',
#  '1560',
#  '1563',
#  '1568',
#  '1570',
#  '1582',
#  '1583',
#  '1584',
#  '1590',
#  '1591',
#  '1593',
#  '1595',
#  '1597',
#  '1603',
#  '1605',
#  '1609',
#  '1611',
#  '1612',
#  '1616',
#  '1617',
#  '1618',
#  '1708',
#  '1709',
#  '1710',
#  '1711',
#  '1712',
#  '1713',
#  '1714',
#  '1717',
#  '1718',
#  '1720',
#  '1721',
#  '1723',
#  '1725',
#  '1726',
#  '1727',
#  '1730',
#  '1731',
#  '1732',
#  '1734',
#  '1735',
#  '1737',
#  '1742',
#  '1762',
#  '1773',
#  '1781',
#  '1783',
#  '1786',
#  '1789',
#  '1795',
#  '1802',
#  '1805',
#  '1809',
#  '1810',
#  '1813',
#  '1815',
#  '1817',
#  '1903',
#  '1904',
#  '1905',
#  '2002',
#  '2006',
#  '2007',
#  '2008',
#  '2010',
#  '2012',
#  '2014',
#  '2015',
#  '2017',
#  '2020',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '2027',
#  '2028',
#  '2029',
#  '2030',
#  '2031',
#  '2032',
#  '2033',
#  '2034',
#  '2038',
#  '2049',
#  '2062',
#  '2063',
#  '2064',
#  '2065',
#  '2066',
#  '2067',
#  '2069',
#  '2102',
#  '2103',
#  '2104',
#  '2105',
#  '2107',
#  '2108',
#  '2208',
#  '2221',
#  '2233',
#  '2235',
#  '2243',
#  '2254',
#  '2301',
#  '2302',
#  '2303',
#  '2305',
#  '2308',
#  '2312',
#  '2313',
#  '2324',
#  '2327',
#  '2328',
#  '2329',
#  '2330',
#  '2331',
#  '2332',
#  '2337',
#  '2338',
#  '2342',
#  '2344',
#  '2345',
#  '2347',
#  '2348A',
#  '2351',
#  '2352',
#  '2353',
#  '2355',
#  '2356',
#  '2359',
#  '2360',
#  '2363',
#  '2365',
#  '2367',
#  '2368',
#  '2369',
#  '2371',
#  '2374',
#  '2382',
#  '2383',
#  '2385',
#  '2387',
#  '2390',
#  '2392',
#  '2393',
#  '2395',
#  '2401',
#  '2406',
#  '2408',
#  '2409',
#  '2412',
#  '2413',
#  '2414',
#  '2415',
#  '2417',
#  '2419',
#  '2420',
#  '2426',
#  '2431',
#  '2436',
#  '2438',
#  '2440',
#  '2441',
#  '2444',
#  '2449',
#  '2450',
#  '2451',
#  '2453',
#  '2454',
#  '2455',
#  '2457',
#  '2459',
#  '2460',
#  '2461',
#  '2462',
#  '2464',
#  '2467',
#  '2471',
#  '2472',
#  '2477',
#  '2478',
#  '2481',
#  '2482',
#  '2483',
#  '2484',
#  '2485',
#  '2486',
#  '2488',
#  '2489',
#  '2492',
#  '2495',
#  '2496',
#  '2511',
#  '2515',
#  '2527',
#  '2535',
#  '2543',
#  '2547',
#  '2605',
#  '2606',
#  '2610',
#  '2612',
#  '2613',
#  '2616',
#  '2618',
#  '2634',
#  '2637',
#  '2645',
#  '2702',
#  '2704',
#  '2723',
#  '2731',
#  '2740',
#  '2801',
#  '2836A',
#  '2849',
#  '2851',
#  '2855',
#  '2867',
#  '2880',
#  '2881A',
#  '2882',
#  '2882A',
#  '2882B',
#  '2883',
#  '2883B',
#  '2884',
#  '2885',
#  '2887',
#  '2887E',
#  '2887F',
#  '2887G',
#  '2887H',
#  '2887Z1',
#  '2889',
#  '2890',
#  '2891',
#  '2891B',
#  '2897',
#  '2903',
#  '2908',
#  '2910',
#  '2911',
#  '2923',
#  '2937',
#  '2945',
#  '2948',
#  '3003',
#  '3004',
#  '3006',
#  '3008',
#  '3010',
#  '3014',
#  '3016',
#  '3017',
#  '3018',
#  '3019',
#  '3023',
#  '3026',
#  '3027',
#  '3028',
#  '3029',
#  '3030',
#  '3031',
#  '3033',
#  '3034',
#  '3036',
#  '3036A',
#  '3037',
#  '3038',
#  '3041',
#  '3042',
#  '3043',
#  '3044',
#  '3049',
#  '3050',
#  '3051',
#  '3054',
#  '3062',
#  '3066',
#  '3071',
#  '3081',
#  '3086',
#  '3088',
#  '3092',
#  '3093',
#  '3094',
#  '3095',
#  '3105',
#  '3122',
#  '3131',
#  '3135',
#  '3138',
#  '3147',
#  '3149',
#  '3152',
#  '3163',
#  '3167',
#  '3169',
#  '3171',
#  '3178',
#  '3189',
#  '3206',
#  '3209',
#  '3211',
#  '3221',
#  '3226',
#  '3228',
#  '3234',
#  '3236',
#  '3260',
#  '3264',
#  '3265',
#  '3285',
#  '3287',
#  '3289',
#  '3290',
#  '5014',
#  '5015',
#  '5016',
#  '5215',
#  '5220',
#  '5222',
#  '5227',
#  '5228',
#  '5234',
#  '5236',
#  '5243',
#  '5245',
#  '5269',
#  '5272',
#  '5274',
#  '5276',
#  '5285',
#  '5288',
#  '5289',
#  '5291',
#  '5292',
#  '5299',
#  '5301',
#  '5302',
#  '5306',
#  '5315',
#  '5324',
#  '5328',
#  '5340',
#  '5347',
#  '5351',
#  '5355',
#  '5356',
#  '5381',
#  '5386',
#  '5388',
#  '5425',
#  '5426',
#  '5434',
#  '5450',
#  '5452',
#  '5460',
#  '5464',
#  '5465',
#  '5469',
#  '5471',
#  '5475',
#  '5478',
#  '5483',
#  '5484',
#  '5488',
#  '5489',
#  '5498',
#  '5511',
#  '5516',
#  '5523',
#  '5529',
#  '5530',
#  '5538',
#  '5601',
#  '5604',
#  '5706',
#  '5864',
#  '5871',
#  '5878',
#  '5903',
#  '5905',
#  '5906',
#  '5907',
#  '6005',
#  '6015',
#  '6016',
#  '6020',
#  '6021',
#  '6024',
#  '6026',
#  '6101',
#  '6104',
#  '6108',
#  '6109',
#  '6113',
#  '6114',
#  '6116',
#  '6120',
#  '6122',
#  '6124',
#  '6126',
#  '6127',
#  '6128',
#  '6129',
#  '6133',
#  '6134',
#  '6138',
#  '6141',
#  '6142',
#  '6146',
#  '6147',
#  '6151',
#  '6152',
#  '6153',
#  '6154',
#  '6155',
#  '6163',
#  '6164',
#  '6167',
#  '6168',
#  '6174',
#  '6176',
#  '6182',
#  '6187',
#  '6189',
#  '6190',
#  '6192',
#  '6196',
#  '6197',
#  '6202',
#  '6205',
#  '6206',
#  '6207',
#  '6209',
#  '6210',
#  '6213',
#  '6215',
#  '6216',
#  '6217',
#  '6220',
#  '6223',
#  '6225',
#  '6226',
#  '6227',
#  '6229',
#  '6230',
#  ...]

# %%
slowk, slowd = data.indicator(
    "STOCH",
    adjust_price=False,
    resample="D",
    fastk_period=9,
    slowk_period=3,
    slowk_matype=0,
    slowd_period=3,
    slowd_matype=0,
    save_to_storage=True,
)

# %%
# 選股策略： 最近一個交易日，ＫＤ值低於３０且五日平均成交量大於１０００張，本益比小於20
kd_low_df = (slowd < 30) & (slowk < 30) & (vol_avg5 >= 1000000) & (pe_ratio <= 20)
kd_low_df = kd_low_df.tail(1)

filtered_symbols = kd_low_df.columns[kd_low_df.iloc[0]].tolist()
df_filtered_symbols = pd.DataFrame(filtered_symbols, columns=['symbol'])

df_filtered_symbols
# Out:
#    symbol
# 0    1229
# 1    1319
# 2    1795
# 3    2474
# 4    2520
# 5    2608
# 6    2610
# 7    2618
# 8    4167
# 9    4763
# 10   5508
# 11   5534
# 12   6179
# 13   6189
# 14   6245
# 15   6472
# 16   6757
# 17   6890
# 18   6962
# 19   9941

# %%
# Assuming you have a DataFrame called stock_name with columns stock_id and stock_name

# Merge df_filtered_symbols with stock_name on stock_id
merged_df = df_filtered_symbols.merge(stock_name, on='symbol')

# Print the merged DataFrame
print(merged_df)
# Out:
#    symbol    公司簡稱
# 0    1229      聯華
# 1    1319      東陽
# 2    1795      美時
# 3    2474      可成
# 4    2520      冠德
# 5    2608    嘉里大榮
# 6    2610      華航
# 7    2618     長榮航
# 8    4167     松瑞藥
# 9    4763  材料*-KY
# 10   5508     永信建
# 11   5534      長虹
# 12   6179      亞通
# 13   6189      豐藝
# 14   6245      立端
# 15   6472      保瑞
# 16   6757    台灣虎航
# 17   6890   來億-KY
# 18   6962   奕力-KY
# 19   9941      裕融

# %%
# 取得篩選股票的本益比
# Step 1: Extract symbols from merged_df
symbols = merged_df['symbol'].tolist()

# Step 2: Filter pe_ratio DataFrame using symbols
filtered_pe_ratio = pe_ratio[symbols]

# Step 3: Retrieve the latest value for each symbol
latest_pe_ratio = filtered_pe_ratio.iloc[-1]

# Print the latest pe_ratio values
print(latest_pe_ratio)
# Out:
# symbol
# 1229    17.52
# 1319    15.28
# 1795    15.47
# 2474    14.01
# 2520     8.96
# 2608    15.02
# 2610     8.50
# 2618     7.88
# 4167    11.84
# 4763     6.18
# 5508    14.88
# 5534    10.24
# 6179    15.43
# 6189    16.96
# 6245    13.13
# 6472    19.49
# 6757    12.98
# 6890    14.50
# 6962    13.01
# 9941    11.40
# Name: 2026-02-26 00:00:00, dtype: float64

# %%
df = pd.DataFrame(latest_pe_ratio).reset_index()
df.columns = ['symbol', 'pe_ratio']

# Merge df_filtered_symbols with stock_name on stock_id
merged_df = merged_df.merge(df, on='symbol')
merged_df.rename(
    columns={
        'symbol': '股票代號', 
        'pe_ratio': '本益比'
    },
    inplace=True
)
merged_df["web_link"] = merged_df["股票代號"].apply(lambda x: f"https://www.wantgoo.com/stock/{x}/technical-chart")
merged_df["題材概念股"] = merged_df["股票代號"].apply(lambda x: tst.read_topic_stocks(x))

merged_df
# Out:
#     股票代號    公司簡稱    本益比                                           web_link  \
# 0   1229      聯華  17.52  https://www.wantgoo.com/stock/1229/technical-c...
# 1   1319      東陽  15.28  https://www.wantgoo.com/stock/1319/technical-c...
# 2   1795      美時  15.47  https://www.wantgoo.com/stock/1795/technical-c...
# 3   2474      可成  14.01  https://www.wantgoo.com/stock/2474/technical-c...
# 4   2520      冠德   8.96  https://www.wantgoo.com/stock/2520/technical-c...
# 5   2608    嘉里大榮  15.02  https://www.wantgoo.com/stock/2608/technical-c...
# 6   2610      華航   8.50  https://www.wantgoo.com/stock/2610/technical-c...
# 7   2618     長榮航   7.88  https://www.wantgoo.com/stock/2618/technical-c...
# 8   4167     松瑞藥  11.84  https://www.wantgoo.com/stock/4167/technical-c...
# 9   4763  材料*-KY   6.18  https://www.wantgoo.com/stock/4763/technical-c...
# 10  5508     永信建  14.88  https://www.wantgoo.com/stock/5508/technical-c...
# 11  5534      長虹  10.24  https://www.wantgoo.com/stock/5534/technical-c...
# 12  6179      亞通  15.43  https://www.wantgoo.com/stock/6179/technical-c...
# 13  6189      豐藝  16.96  https://www.wantgoo.com/stock/6189/technical-c...
# 14  6245      立端  13.13  https://www.wantgoo.com/stock/6245/technical-c...
# 15  6472      保瑞  19.49  https://www.wantgoo.com/stock/6472/technical-c...
# 16  6757    台灣虎航  12.98  https://www.wantgoo.com/stock/6757/technical-c...
# 17  6890   來億-KY  14.50  https://www.wantgoo.com/stock/6890/technical-c...
# 18  6962   奕力-KY  13.01  https://www.wantgoo.com/stock/6962/technical-c...
# 19  9941      裕融  11.40  https://www.wantgoo.com/stock/9941/technical-c...
#
#                                                 題材概念股
# 0   '台積電概念股', '氫能概念股', '都市更新概念股', '智慧城市展概念股', '傳產內...
# 1   '大陸收成股', '台幣貶值受惠概念股', '特斯拉概念股', '臺灣中型100指數成分股'...
# 2   '台商美國概念股', '再生醫療概念股', '情人節概念股', '臺灣中型100指數成分股'...
# 3   'AI PC概念股', 'Apple概念股', 'CES概念股', 'ESG概念股', 'i...
# 4    'CSR(企業社會責任)概念股', '桃園航空城概念股', '都市更新概念股', '傳產內需股'
# 5   '大陸收成股', '光棍節(雙11)受惠概念股', '物流概念股', '桃園航空城概念股',...
# 6   'ESG概念股', '桃園航空城概念股', '基金重押股', '陸客來台概念股', '暑假概...
# 7   'ESG概念股', '一帶一路概念股', '台幣貶值受惠概念股', '桃園航空城概念股', ...
# 8                                             '防疫概念股'
# 9   'AI智慧眼鏡概念股', '台積電概念股', '臺灣中型100指數成分股', '臺灣發達指數...
# 10                                          '都市更新概念股'
# 11                                 '都市更新概念股', '傳產內需股'
# 12
# 13                                      '鈣鈦礦太陽能電池概念股'
# 14  '5G概念股', 'MWC概念股', '人工智慧AI概念股', '軍工概念股', '無人機概...
# 15  '台商美國概念股', '再生醫療概念股', '臺灣中型100指數成分股', '臺灣發達指數成分股'
# 16                                          '陸客來台概念股'
# 17               '奧運概念股', '臺灣中型100指數成分股', '臺灣發達指數成分股'
# 18
# 19  'ESG概念股', '大陸收成股', '電動車充電概念股', '臺灣中型100指數成分股',...

# %% [markdown]
# ## 輸出結果至Google sheet

# %%
# Google SpreadSheet 公用程式初始化
gspread_mgr = gsm.GspreadManager()
gspread_wb = gspread_mgr.get_spreadsheet(GSPERAD_SHEET_KEY)

print(f"更新Google 表單：{gspread_wb.title}，工作表：{OUTPUT_GSHEET_NAME}")
# Out:
# 更新Google 表單：台股選股清單，工作表：選股清單01

# %%
# 刪除再重建工作表
gspread_mgr.recreate_worksheet(GSPERAD_SHEET_KEY, OUTPUT_GSHEET_NAME)

# %%
# 更新工作表資料
gspread_mgr.update_worksheet_values(
    GSPERAD_SHEET_KEY, 
    OUTPUT_GSHEET_NAME, 
    [merged_df.columns.values.tolist()] + merged_df.values.tolist()
)

# %%
# Update 報表更新日期資訊
now_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# Update the cell with the current datetime
info_sheet = gspread_mgr.get_worksheet(GSPERAD_SHEET_KEY, "更新日誌")
info_sheet.update_cell(1, 2, now_str)
# Out:
# {'spreadsheetId': '1ovvtmFtsc9Se8r6px2NRferACDckIoOnZJ2__AUwyO8',
#  'updatedRange': "'更新日誌'!B1",
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
# 計算總執行時間
end_time = datetime.now()
total_time = end_time - start_time

print(f"分析結束時間: {end_time}")
print(f"總執行時間: {total_time}")
# Out:
# 分析結束時間: 2026-02-27 16:24:32.504348
# 總執行時間: 0:00:10.540167
